# %%
import time
from datetime import datetime
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchWindowException
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome()
driver.maximize_window()
driver.get(' https://www.myntra.com/men-tshirts');

time.sleep(3)

# %%
xx = driver.find_elements(By.CSS_SELECTOR, "h4.product-product")

# %%
for n, x in enumerate(xx): # n is the index and x is the element in xx:
    print(n+1, x.text)

# %%
class Scrape_Data:
    def __init__(self,
               URL="https://www.myntra.com/men-tshirts", page_from:int=1, page_to:int=1, check_point = 500):
        self.URL = URL
        self.page_from = f"?p={str(page_from)}"
        self.page_to = f"?p={str(page_to)}"
        self.CSS = By.CSS_SELECTOR
        self.CSS_NAME = By.CLASS_NAME
        self.XPATH = By.XPATH
        try:
            self.driver = webdriver.Chrome()
            self.driver.get(self.URL+self.page_from )
            #self.driver.maximize_window()
            time.sleep(1)

        except Exception as e:
            print(e)
        self.data = {'Brand': [], 'Desc': [], 'DetailedDesc': [],
                'DiscountPrice': [], 'OriginalPrice': [], 'DiscountPercentage': [],
                'ProductLink': [], 'Images': [], 'ZoomedImages': []}
        self.check_point = check_point
    
    def search_elements(self, value:str = None):
       try:
           return self.driver.find_elements(self.CSS, value)
       except Exception as e:
           print(e)

    def save_to_csv(self, page = None, total_data_points = None):
        df = pd.DataFrame(self.data)
        formatted_today_date = datetime.now().strftime("%d_%m_%y")
        format = f"tshirts_{formatted_today_date}_pg{page}_cp_{total_data_points}.csv"
        df.to_csv(format,index = False, encoding = 'utf-8-sig')
        print(f"File saved as: {format}\n-------------------------------------------------------")

# %%
trial = Scrape_Data(check_point=50)

# %%
trial.URL+trial.page_to
# Out:
# 'https://www.myntra.com/men-tshirts?p=1'

# %%
Elements = trial.search_elements(value="li.product-base")

# %%
image_srcset = Elements[1].find_element(By.CSS_SELECTOR, "source").get_attribute("srcset")

# %%
trial.elements_by_text(Elements[0], "product-brand")
# Out:
# 'HERE&NOW'

# %%
image_srcset
# Out:
# '\n    https://assets.myntassets.com/f_webp,dpr_1.0,q_60,w_210,c_limit,fl_progressive/assets/images/18239082/2022/7/27/e8bb8557-edbd-4115-9d87-c89acb1606a31658919552237-HERENOW-Men-Tshirts-7651658919551754-1.jpg ,\n    https://assets.myntassets.com/f_webp,dpr_1.5,q_60,w_210,c_limit,fl_progressive/assets/images/18239082/2022/7/27/e8bb8557-edbd-4115-9d87-c89acb1606a31658919552237-HERENOW-Men-Tshirts-7651658919551754-1.jpg 1.5x,\n    https://assets.myntassets.com/f_webp,dpr_1.8,q_60,w_210,c_limit,fl_progressive/assets/images/18239082/2022/7/27/e8bb8557-edbd-4115-9d87-c89acb1606a31658919552237-HERENOW-Men-Tshirts-7651658919551754-1.jpg 1.8x,\n    https://assets.myntassets.com/f_webp,dpr_2.0,q_60,w_210,c_limit,fl_progressive/assets/images/18239082/2022/7/27/e8bb8557-edbd-4115-9d87-c89acb1606a31658919552237-HERENOW-Men-Tshirts-7651658919551754-1.jpg 2.0x,\n    https://assets.myntassets.com/f_webp,dpr_2.2,q_60,w_210,c_limit,fl_progressive/assets/images/18239082/2022/7/27/e8bb8557-edbd-4115-
# ...

# %% [markdown]
# <li class="product-base"><div class="product-thumbShim"></div><div class="product-ratingsContainer"><span>3.7</span><span class="myntraweb-sprite product-starIcon index-productRatingsGoodIcon sprites-productRatingsGoodIcon"></span><div class="product-ratingsCount"><div class="product-separator">|</div><!-- react-text: 440 -->1.2k<!-- /react-text --></div></div><a data-refreshpage="true" target="_blank" href="tshirts/bullmer/bullmer-graphic-printed-round-neck-oversized-cotton-t-shirt/24014326/buy" style="display: block;"><div class="product-imageSliderContainer"><div class="product-sliderContainer" style="display: block;"><div style="background: rgb(255, 237, 243);"><div style="height: 280px; width: 100%;"><picture draggable="false" class="img-responsive" style="width: 100%; height: 100%; display: block;"><source srcset="
#     https://assets.myntassets.com/f_webp,dpr_1.0,q_60,w_210,c_limit,fl_progressive/assets/images/24014326/2023/7/14/c3bb4dd9-b557-4602-a885-f77b445645bc1689274870298BULLMERMenBlackTypographyPrintedPocketsT-shirt1.jpg ,
#     https://assets.myntassets.com/f_webp,dpr_1.5,q_60,w_210,c_limit,fl_progressive/assets/images/24014326/2023/7/14/c3bb4dd9-b557-4602-a885-f77b445645bc1689274870298BULLMERMenBlackTypographyPrintedPocketsT-shirt1.jpg 1.5x,
#     https://assets.myntassets.com/f_webp,dpr_1.8,q_60,w_210,c_limit,fl_progressive/assets/images/24014326/2023/7/14/c3bb4dd9-b557-4602-a885-f77b445645bc1689274870298BULLMERMenBlackTypographyPrintedPocketsT-shirt1.jpg 1.8x,
#     https://assets.myntassets.com/f_webp,dpr_2.0,q_60,w_210,c_limit,fl_progressive/assets/images/24014326/2023/7/14/c3bb4dd9-b557-4602-a885-f77b445645bc1689274870298BULLMERMenBlackTypographyPrintedPocketsT-shirt1.jpg 2.0x,
#     https://assets.myntassets.com/f_webp,dpr_2.2,q_60,w_210,c_limit,fl_progressive/assets/images/24014326/2023/7/14/c3bb4dd9-b557-4602-a885-f77b445645bc1689274870298BULLMERMenBlackTypographyPrintedPocketsT-shirt1.jpg 2.2x,
#     https://assets.myntassets.com/f_webp,dpr_2.4,q_60,w_210,c_limit,fl_progressive/assets/images/24014326/2023/7/14/c3bb4dd9-b557-4602-a885-f77b445645bc1689274870298BULLMERMenBlackTypographyPrintedPocketsT-shirt1.jpg 2.4x,
#     https://assets.myntassets.com/f_webp,dpr_2.6,q_60,w_210,c_limit,fl_progressive/assets/images/24014326/2023/7/14/c3bb4dd9-b557-4602-a885-f77b445645bc1689274870298BULLMERMenBlackTypographyPrintedPocketsT-shirt1.jpg 2.6x,
#     https://assets.myntassets.com/f_webp,dpr_2.8,q_60,w_210,c_limit,fl_progressive/assets/images/24014326/2023/7/14/c3bb4dd9-b557-4602-a885-f77b445645bc1689274870298BULLMERMenBlackTypographyPrintedPocketsT-shirt1.jpg 2.8x" type="image/webp"><img draggable="false" src="https://assets.myntassets.com/dpr_2,q_60,w_210,c_limit,fl_progressive/assets/images/24014326/2023/7/14/c3bb4dd9-b557-4602-a885-f77b445645bc1689274870298BULLMERMenBlackTypographyPrintedPocketsT-shirt1.jpg" class="img-responsive" alt="BULLMER Graphic Printed Round Neck Oversized Cotton T-shirt" title="BULLMER Graphic Printed Round Neck Oversized Cotton T-shirt" style="width: 100%; display: block;"></picture></div></div></div></div><div class="product-productMetaInfo"><h3 class="product-brand">BULLMER</h3><h4 class="product-product">Oversized Cotton T-shirt</h4><h4 class="product-sizes"><!-- react-text: 453 -->Sizes: <!-- /react-text --><span class="product-sizeInventoryPresent">XL</span></h4><div class="product-price"><span><span class="product-discountedPrice"><!-- react-text: 458 -->Rs. <!-- /react-text --><!-- react-text: 459 -->389<!-- /react-text --></span><span class="product-strike"><!-- react-text: 461 -->Rs. <!-- /react-text --><!-- react-text: 462 -->1499<!-- /react-text --></span></span><span class="product-discountPercentage">(74% OFF)</span></div></div></a><div class="image-grid-similarColorsCta product-similarItemCta"><span class="myntraweb-sprite image-grid-similarColorsIcon sprites-similarProductsIcon"></span><span class="image-grid-iconText">VIEW SIMILAR</span></div><div class="product-actions "><span class="product-wishlistFlex product-actionsButton product-wishlist " style="width: 100%; text-align: center;"><span class="myntraweb-sprite product-notWishlistedIcon sprites-notWishlisted"></span><!-- react-text: 470 -->wishlist<!-- /react-text --></span></div><div class="product-sizeDisplayDiv"><div class="product-sizeDisplayHeader"><span>Select a size</span><span class="myntraweb-sprite product-sizeDisplayRemoveMark sprites-remove"></span></div><div class="product-sizeButtonsContaier"><button class="product-sizeButton">XL</button></div></div></li>

# %% [markdown]
# <li class="product-base"><div class="product-thumbShim"></div><div class="product-ratingsContainer"><span>4.2</span><span class="myntraweb-sprite product-starIcon index-productRatingsExcellentIcon sprites-productRatingsExcellentIcon"></span><div class="product-ratingsCount"><div class="product-separator">|</div><!-- react-text: 835 -->11.1k<!-- /react-text --></div></div><a data-refreshpage="true" target="_blank" href="tshirts/h%26m/hm-men-white-solid-cotton-pure-cotton-t-shirt-regular-fit/11468714/buy" style="display: block;"><div class="product-imageSliderContainer"><div class="product-sliderContainer" style="display: block;"><div style="background: rgb(229, 241, 255);"><div style="height: 280px; width: 100%;"><picture draggable="false" class="img-responsive" style="width: 100%; height: 100%; display: block;"><source srcset="
#     https://assets.myntassets.com/f_webp,dpr_1.0,q_60,w_210,c_limit,fl_progressive/assets/images/11468714/2022/2/7/cbdd604f-1341-47a9-92c6-2fe6078e89821644231911509-HM-Men-White-Solid-Cotton-Pure-Cotton-T-shirt-Regular-Fit-42-1.jpg ,
#     https://assets.myntassets.com/f_webp,dpr_1.5,q_60,w_210,c_limit,fl_progressive/assets/images/11468714/2022/2/7/cbdd604f-1341-47a9-92c6-2fe6078e89821644231911509-HM-Men-White-Solid-Cotton-Pure-Cotton-T-shirt-Regular-Fit-42-1.jpg 1.5x,
#     https://assets.myntassets.com/f_webp,dpr_1.8,q_60,w_210,c_limit,fl_progressive/assets/images/11468714/2022/2/7/cbdd604f-1341-47a9-92c6-2fe6078e89821644231911509-HM-Men-White-Solid-Cotton-Pure-Cotton-T-shirt-Regular-Fit-42-1.jpg 1.8x,
#     https://assets.myntassets.com/f_webp,dpr_2.0,q_60,w_210,c_limit,fl_progressive/assets/images/11468714/2022/2/7/cbdd604f-1341-47a9-92c6-2fe6078e89821644231911509-HM-Men-White-Solid-Cotton-Pure-Cotton-T-shirt-Regular-Fit-42-1.jpg 2.0x,
#     https://assets.myntassets.com/f_webp,dpr_2.2,q_60,w_210,c_limit,fl_progressive/assets/images/11468714/2022/2/7/cbdd604f-1341-47a9-92c6-2fe6078e89821644231911509-HM-Men-White-Solid-Cotton-Pure-Cotton-T-shirt-Regular-Fit-42-1.jpg 2.2x,
#     https://assets.myntassets.com/f_webp,dpr_2.4,q_60,w_210,c_limit,fl_progressive/assets/images/11468714/2022/2/7/cbdd604f-1341-47a9-92c6-2fe6078e89821644231911509-HM-Men-White-Solid-Cotton-Pure-Cotton-T-shirt-Regular-Fit-42-1.jpg 2.4x,
#     https://assets.myntassets.com/f_webp,dpr_2.6,q_60,w_210,c_limit,fl_progressive/assets/images/11468714/2022/2/7/cbdd604f-1341-47a9-92c6-2fe6078e89821644231911509-HM-Men-White-Solid-Cotton-Pure-Cotton-T-shirt-Regular-Fit-42-1.jpg 2.6x,
#     https://assets.myntassets.com/f_webp,dpr_2.8,q_60,w_210,c_limit,fl_progressive/assets/images/11468714/2022/2/7/cbdd604f-1341-47a9-92c6-2fe6078e89821644231911509-HM-Men-White-Solid-Cotton-Pure-Cotton-T-shirt-Regular-Fit-42-1.jpg 2.8x" type="image/webp"><img draggable="false" src="https://assets.myntassets.com/dpr_2,q_60,w_210,c_limit,fl_progressive/assets/images/11468714/2022/2/7/cbdd604f-1341-47a9-92c6-2fe6078e89821644231911509-HM-Men-White-Solid-Cotton-Pure-Cotton-T-shirt-Regular-Fit-42-1.jpg" class="img-responsive" alt="HM Men White Solid Cotton Pure Cotton T-shirt Regular Fit" title="HM Men White Solid Cotton Pure Cotton T-shirt Regular Fit" style="width: 100%; display: block;"></picture></div></div></div></div><div class="product-productMetaInfo"><h3 class="product-brand">H&amp;M</h3><h4 class="product-product">Cotton Pure Cotton T-shirt Regular Fit</h4><h4 class="product-sizes"><!-- react-text: 848 -->Sizes: <!-- /react-text --><span class="product-sizeInventoryPresent">XS</span></h4><div class="product-price"><span><!-- react-text: 852 -->Rs. <!-- /react-text --><!-- react-text: 853 -->399<!-- /react-text --></span><!-- react-text: 854 --><!-- /react-text --></div></div></a><div class="image-grid-similarColorsCta product-similarItemCta"><span class="myntraweb-sprite image-grid-similarColorsIcon sprites-similarProductsIcon"></span><span class="image-grid-iconText">VIEW SIMILAR</span></div><div class="product-actions "><span class="product-wishlistFlex product-actionsButton product-wishlist " style="width: 100%; text-align: center;"><span class="myntraweb-sprite product-notWishlistedIcon sprites-notWishlisted"></span><!-- react-text: 861 -->wishlist<!-- /react-text --></span></div><div class="product-sizeDisplayDiv"><div class="product-sizeDisplayHeader"><span>Select a size</span><span class="myntraweb-sprite product-sizeDisplayRemoveMark sprites-remove"></span></div><div class="product-sizeButtonsContaier"><button class="product-sizeButton">XS</button></div></div></li>

# %% [markdown]
# <div class="product-price"><span><!-- react-text: 1694 -->Rs. <!-- /react-text --><!-- react-text: 1695 -->399<!-- /react-text --></span><!-- react-text: 1696 --><!-- /react-text --></div>

# %%
driver = webdriver.Chrome()
driver.maximize_window()
driver.get(' https://www.myntra.com/men-tshirts');
Elements = driver.find_elements(By.CSS_SELECTOR, "li.product-base")

# %%
try:
    image_srcset = Elements[0].find_element(By.CSS_SELECTOR, "source").get_attribute("srcset")
    image_urls = [url.strip() for url in image_srcset.split('\n')]
    image_url = image_urls[1]
    zoomed_image_url= image_urls[2:]

except:image_srcset = None

# %%
image_urls[1]
# Out:
# 'https://assets.myntassets.com/f_webp,dpr_1.0,q_60,w_210,c_limit,fl_progressive/assets/images/25072090/2023/9/30/6be97619-12fc-40c3-a91b-b5d5f13ba8181696013416163StormbornMenBlackPrintedRawEdgeT-shirt1.jpg ,'

# %%
for i in range(len(Elements)):
    try:
        original_price = Elements[i].find_element(By.CLASS_NAME, "product-discountedPrice").text
        
    except:
        original_price = Elements[i].find_element(By.XPATH, ".//div[@class='product-price']/span").text

# %%
a,b = 1,10

no_of_pages = list(range(1,b+1))
no_of_pages

for i in no_of_pages:
    print(i*50)

# %%
page_from, page_to= 1,100
trial = Scrape_Data(URL="https://www.myntra.com/men-tshirts",page_from=page_from,page_to=page_to,check_point=500)  # URL="https://www.myntra.com/men-tshirts?p=11", ckeck_point=50

page_count = 1
total_data_points = 0
try:
    for j in range(page_from,(page_to)+1):
        Elements = trial.search_elements(value="li.product-base")

        if len(Elements) != 0:

            for i in range(len(Elements)):
                
            #Elements[1].find_element(By.CSS_SELECTOR, "div.product-productMetaInfo.h3.product-brand").text
                try:product_brand = Elements[i].find_element(By.CLASS_NAME, "product-brand").text
                except:product_brand = None
                try:product_name = Elements[i].find_element(By.CLASS_NAME, "product-product").text
                except:product_name = None
                try:sizes_available = Elements[i].find_element(By.CLASS_NAME, "product-sizeInventoryPresent").text
                except:sizes_available = None
                try:discounted_price = Elements[i].find_element(By.CLASS_NAME, "product-discountedPrice").text
                except:discounted_price = None
                try:original_price = Elements[i].find_element(By.CLASS_NAME, "product-strike").text
                except:original_price = Elements[i].find_element(By.XPATH, ".//div[@class='product-price']/span").text
                try:discount_percentage = Elements[i].find_element(By.CLASS_NAME, "product-discountPercentage").text
                except:discount_percentage = None


                # Extracting the Product links
                try:product_link = Elements[i].find_element(By.CSS_SELECTOR, "a[data-refreshpage='true']").get_attribute("href")
                except:product_link = None

                # Extracting the Image links
                try:
                    image_srcset = Elements[i].find_element(By.CSS_SELECTOR, "source").get_attribute("srcset")
                    image_urls = [url.strip() for url in image_srcset.split('\n')]
                    image_url = image_urls[1]
                    zoomed_image_url= image_urls[2:]
                except:image_srcset = None
                

                # Appending Extracted data points in required column names
                trial.data['Brand'].append(product_brand)
                trial.data['Desc'].append(product_name)
                trial.data['DiscountPrice'].append(discounted_price)
                trial.data['OriginalPrice'].append(original_price)
                trial.data['DiscountPercentage'].append(discount_percentage)
                trial.data['ProductLink'].append(product_link)
                trial.data['DetailedDesc'].append(product_link.split("/")[-3].replace("-", " ").title()) # Extracting Detailed Description from link
                trial.data['Images'].append(image_url)
                trial.data['ZoomedImages'].append(zoomed_image_url)
                # Getting Total Data Points
                total_data_points += 1

            # Next Page
            trial.driver.find_element(By.CSS_SELECTOR,"li.pagination-next").click()
            print(f"Progress: Page {j} || Data Collected: {50*(page_count)}\n-------------------------------------------------------")
            page_count += 1

            # Saving Data at given check point
            if total_data_points % trial.check_point == 0:
                trial.save_to_csv(page=j,total_data_points=total_data_points),

                                                
except Exception as e:
    trial.save_to_csv(page=j, total_data_points=total_data_points)
    print(f"An error occurred: {e}")

finally:
    trial.driver.close()
# Out:
# Progress: Page 1 || Data Collected: 50
# -------------------------------------------------------
# Progress: Page 2 || Data Collected: 100
# -------------------------------------------------------
# Progress: Page 3 || Data Collected: 150
# -------------------------------------------------------
# Progress: Page 4 || Data Collected: 200
# -------------------------------------------------------
# Progress: Page 5 || Data Collected: 250
# -------------------------------------------------------
# Progress: Page 6 || Data Collected: 300
# -------------------------------------------------------
# Progress: Page 7 || Data Collected: 350
# -------------------------------------------------------
# Progress: Page 8 || Data Collected: 400
# -------------------------------------------------------
# Progress: Page 9 || Data Collected: 450
# -------------------------------------------------------
# Progress: Page 10 || Data Collected: 500
# -------------------------------------------------------
# ...

# %%
for i in range(1, 11):
    if i % 2 == 0:
        print(i)
        if i == 2:
            print(f"When count is 2, i = {i}")

# %%
type(trial.page_from)
# Out:
# str

# %%
data = {
    'Brand': [],
    'Desc': [],
    'DetailedDesc': [],
    'DiscountPrice': [],
    'OriginalPrice': [],
    'DiscountPercentage': [],
    'ProductLink': [],
    'Images': [],
    'ZoomedImages': []}
for i in data.keys():
    print(i, len(data[i]))
# Out:
# Brand 50
# Desc 50
# DetailedDesc 50
# DiscountPrice 50
# OriginalPrice 50
# DiscountPercentage 50
# ProductLink 50
# Images 50
# ZoomedImages 50

# %%
df = pd.DataFrame(data)
df.shape
# Out:
# (50, 9)

# %%
df
# Out:
#                     Brand                                          Desc  \
# 0               Stormborn                 Oversized Pure Cotton T-shirt
# 1                 BULLMER                        Printed Cotton T-shirt
# 2                HERE&NOW                       Men Pure Cotton T-shirt
# 3                Roadster                     Colourblocked Pure Cotton
# 4                 Elibolz                      Oversized Cotton T-shirt
# 5                 BULLMER                      Oversized Cotton T-shirt
# 6               Stormborn                 Pure Cotton Oversized T-shirt
# 7                Roadster                     Men Solid Knitted T-shirt
# 8                Roadster                         Colourblocked T-shirt
# 9                HERE&NOW                           Pure Cotton T-shirt
# 10                    H&M        Cotton Pure Cotton T-shirt Regular Fit
# 11               Roadster                      Solid Round Neck T-shirt
# ...

# %%
detailed_desc = "https://www.myntra.com/tshirts/hrx+by+hrithik+roshan/hrx-by-hrithik-roshan-men-solid-high-neck-t-shirt/25910218/buy"

# %%
detailed_desc.split("/")[-3].replace("-", " ").title()
# Out:
# 'Hrx By Hrithik Roshan Men Solid High Neck T Shirt'

# %%
trial.driver.find_element(By.XPATH, "//h1[@class='pdp-name']").text
# Out:
# 'Graphic Printed Oversized Drop Shoulder Sleeves Pure Cotton T-shirt'

# %%
from datetime import datetime
formatted_today_date = datetime.now().strftime("%d_%m_%y")
print(f"tshirts_{formatted_today_date}_cp_{500}.csv")
# Out:
# tshirts_21_01_24_cp_500.csv

# %%
df.to_csv(f"tshirts_{formatted_today_date}_cp_{500}.csv",index = False,encoding = 'utf-8-sig')
#df.to_json('Flipkart_3rdDec23.json',index = False)

# %%
detail_dec = driver.get(product_link)

# %%
driver = webdriver.Chrome()
driver.get(product_link)
ElementBoxes = driver.find_elements(By.CSS_SELECTOR,"h1.pdp-name")
ElementBoxes[0].text
driver.close()

# %%
txt = trial_1.search_elements(value="h1.pdp-name")
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="90e22bfca506e6c6a9019f08d0fa3499", element="A58A57F42A9FE9E67B5A3275A01A2238_element_46")>]

# %%
txt[0].text
# Out:
# 'Men White Pure Cotton T-shirt'

# %%
image_urls
# Out:
# ['',
#  'https://assets.myntassets.com/f_webp,dpr_1.0,q_60,w_210,c_limit,fl_progressive/assets/images/18239082/2022/7/27/e8bb8557-edbd-4115-9d87-c89acb1606a31658919552237-HERENOW-Men-Tshirts-7651658919551754-1.jpg ,',
#  'https://assets.myntassets.com/f_webp,dpr_1.5,q_60,w_210,c_limit,fl_progressive/assets/images/18239082/2022/7/27/e8bb8557-edbd-4115-9d87-c89acb1606a31658919552237-HERENOW-Men-Tshirts-7651658919551754-1.jpg 1.5x,',
#  'https://assets.myntassets.com/f_webp,dpr_1.8,q_60,w_210,c_limit,fl_progressive/assets/images/18239082/2022/7/27/e8bb8557-edbd-4115-9d87-c89acb1606a31658919552237-HERENOW-Men-Tshirts-7651658919551754-1.jpg 1.8x,',
#  'https://assets.myntassets.com/f_webp,dpr_2.0,q_60,w_210,c_limit,fl_progressive/assets/images/18239082/2022/7/27/e8bb8557-edbd-4115-9d87-c89acb1606a31658919552237-HERENOW-Men-Tshirts-7651658919551754-1.jpg 2.0x,',
# ...

# %%
image_urls = [url.strip() for url in image_srcset.split('\n')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[156], line 1
# ----> 1 image_urls = [url.strip() for url in image_srcset.split('\n')]
#
# AttributeError: 'NoneType' object has no attribute 'split'

# %%
# Assuming average time for 5,000 data points is between 17 to 18 minutes
average_time_per_data_point = (17 + 18) / 2  # Taking the average of 17 and 18 minutes

# Number of data points
total_data_points = 120000

# Calculate total time for 120,000 data points
total_time_for_120000_data_points = average_time_per_data_point * (total_data_points / 5000)

print(f"Estimated total time to scrape 120,000 data points: {total_time_for_120000_data_points:.2f} minutes")
# Out:
# Estimated total time to scrape 120,000 data points: 420.00 minutes
